df['aqsum']=df.select(lambda col: col.startswith('aq'), axis=1).sum(axis=1)
df['bqsum']=df.select(lambda col: col.startswith('bq'), axis=1).sum(axis=1)
#for i in range(1, 30):
#           3 df['bqsum'] = df[['aq%s' % i]].sum
#            data_rnn['bqq%s' % i] = data_rnn[['b%s' % i, 'bq%s' % i]].product(axis=1)
df.head(20)
# Out:
#      id   trade_px  trade_volume       b1        b2        b3        b4  \
# 0     3  10303.705      0.000000  10303.7  10302.96  10302.87  10302.42
# 1     8  10303.705      0.000000  10303.7  10302.96  10302.87  10302.42
# 2    13  10303.705      0.000000  10303.7  10302.96  10302.87  10302.42
# 3    18  10303.705      0.000000  10303.7  10302.96  10302.87  10302.42
# 4    24  10303.705      0.000000  10303.7  10302.96  10302.87  10302.42
# 5    28  10303.705      0.000000  10303.7  10302.96  10302.87  10302.42
# 6    33  10303.705      0.000000  10303.7  10302.96  10302.87  10302.42
# 7    38  10303.705      0.000000  10303.7  10302.96  10302.87  10302.42
# 8    43  10303.705      0.000000  10303.7  10302.96  10302.87  10302.42
# 9    51  10303.705      0.000000  10303.7  10302.96  10302.87  10302.42
# 10   58  10303.705      0.000000  10303.7  10302.96  10302.87  10302.42
# 11   67  10303.705      0.000000  10303.7  10302.96  10302.87  10302.42
# ...

# %%
df['aqsum5']= df['aq1']+df['aq2']+df['aq3']+df['aq4']+df['aq5']
df['bqsum5']= df['bq1']+df['bq2']+df['bq3']+df['aq4']+df['aq5']
df['aqsum3']= df['aq1']+df['aq2']+df['aq3']
df['bqsum3']= df['bq1']+df['bq2']+df['bq3']
df['abq']= df['aq1']-df['bq1']
df['abq5']= df['aqsum5']-df['bqsum5']
df['distRatio5']=(df['trade_px']-df['b5'])-(df['a5']-df['trade_px'])
df['distRatio10']=(df['trade_px']-df['b5'])-(df['a5']-df['trade_px'])

# %%
tdt=pd.to_datetime(df.trades_date_time).to_frame()


tdt['sign_vol']=df['sign_vol']
tdt.index = pd.to_datetime(df['trades_date_time'])
tdt=tdt.drop(tdt.index[:5])
tdt = tdt.resample('s').mean()
tdt=tdt.interpolate(method='linear')
tdt.index.rename('order_date_time', inplace=True)
tdt['sign_vol']=tdt['sign_vol'].rolling(window= 5, center=False).mean()
tdt.head(2)
# Out:
#                      sign_vol
# order_date_time
# 2018-02-27 07:09:21       NaN
# 2018-02-27 07:09:22       NaN

# %%
#date_time=pd.to_datetime(df.trades_date_time).to_frame()
odt=pd.to_datetime(df.order_date_time).to_frame()
odt["Spread"] = df["a1"]-df["b1"]
odt['trade_px']=df['trade_px']

odt["a1"] = df["a1"]
odt["b1"] = df["b1"]
odt["aq1"] = df["aq1"]
odt["bq1"] = df["bq1"]
odt["aqsum5"] = df["aqsum5"]
odt["bqsum5"] = df["bqsum5"]
odt["aqsum3"] = df["aqsum3"]
odt["bqsum3"] = df["bqsum3"]
odt["aqsum"] = df["aqsum"]
odt["bqsum"] = df["bqsum"]
odt['abq']=df['abq']
odt['abq5']=df['abq5']
odt['abratio']= df['aq1']/(df['aq1']+df['bq1'])
odt['id']=df['id']
odt['distRatio5']=df['distRatio5']
odt['distRatio10']=df['distRatio10']
#.rolling(window= 1, center=False).mean()

# %%
#date_time_vol=date_time.join(df["trade_volume"])
#sign=df["trade_volume"].subtract(df["aq1"])
#sign=date_time_vol["sign"].add(0.0001)
#sign[sign >= 0] = 1
#sign[sign < 0] = -1
odt["trade_volume"]=df["trade_volume"]
#.multiply(sign)

# %%
odt=odt.drop(odt.index[:5])
odt.head(2)
# Out:
#              order_date_time  Spread   trade_px        a1       b1        aq1  \
# 5 2018-02-27 07:09:11.973009    0.01  10303.705  10303.71  10303.7  16.575512
# 6 2018-02-27 07:09:13.517520    0.01  10303.705  10303.71  10303.7  16.575512
#
#         bq1     aqsum5    bqsum5     aqsum3    bqsum3      aqsum      bqsum  \
# 5  0.008913  25.514852  8.869253  16.676512  0.030913  63.586402  14.175087
# 6  0.008913  17.717734  1.000253  16.748394  0.030913  63.651784  14.175778
#
#          abq       abq5   abratio  id  distRatio5  distRatio10  trade_volume
# 5  16.566599  16.645599  0.999463  28        1.35         1.35           0.0
# 6  16.566599  16.717481  0.999463  33        1.39         1.39           0.0

# %%
odt.index = pd.to_datetime(odt['order_date_time'])
odt = odt.resample('s').mean()
odt=odt.interpolate(method='linear')

odt.head(2)
# Out:
#                      Spread   trade_px        a1       b1        aq1  \
# order_date_time
# 2018-02-27 07:09:11    0.01  10303.705  10303.71  10303.7  16.575512
# 2018-02-27 07:09:12    0.01  10303.705  10303.71  10303.7  16.575512
#
#                           bq1     aqsum5    bqsum5     aqsum3    bqsum3  \
# order_date_time
# 2018-02-27 07:09:11  0.008913  25.514852  8.869253  16.676512  0.030913
# 2018-02-27 07:09:12  0.008913  21.616293  4.934753  16.712453  0.030913
#
#                          aqsum      bqsum        abq       abq5   abratio  \
# order_date_time
# 2018-02-27 07:09:11  63.586402  14.175087  16.566599  16.645599  0.999463
# 2018-02-27 07:09:12  63.619093  14.175433  16.566599  16.681540  0.999463
#
#                        id  distRatio5  distRatio10  trade_volume
# order_date_time
# 2018-02-27 07:09:11  28.0        1.35         1.35           0.0
# 2018-02-27 07:09:12  30.5        1.37         1.37           0.0

# %%
tdt.head(10)
# Out:
#                      sign_vol
# order_date_time
# 2018-02-27 07:09:21       NaN
# 2018-02-27 07:09:22       NaN
# 2018-02-27 07:09:23       NaN
# 2018-02-27 07:09:24       NaN
# 2018-02-27 07:09:25  0.005177
# 2018-02-27 07:09:26  0.003265
# 2018-02-27 07:09:27  0.001353
# 2018-02-27 07:09:28 -0.000559
# 2018-02-27 07:09:29 -0.002470
# 2018-02-27 07:09:30 -0.004382

# %%
#odt['abqdt']=pd.rolling_mean((odt['aq1']-odt['bq1']), 15)
odt['abqdt']=(odt['abq']-(odt['abq'].shift(-1))).rolling(window= 2, center=False).mean()

odt['abqdt^2']=(odt['abqdt']-(odt['abqdt'].shift(-1)))

#odt['abqdt']=(odt['aq1']-odt['bq1']).rolling(window= 15, center=False).mean()
odt['rollingRatio']=odt['abratio'].rolling(window= 5, center=False).mean()
odt['ratio3']=odt['aqsum3']/(odt['aqsum3']+odt['bqsum3'])
odt['ratio5']=odt['aqsum5']/(odt['aqsum5']+odt['bqsum5'])
odt['ratio5dt']=(odt['ratio5']-(odt['ratio5'].shift(-1))).rolling(window= 2, center=False).mean()
odt=pd.concat([odt, tdt], axis=1)
odt['abqsum']=odt['aqsum']-odt['bqsum']
# 2018-02-27 07:13:45  0.010000  10328.435000  10328.44  10328.430000
# 2018-02-27 07:13:50  0.010000  10332.675000  10332.68  10332.670000
# 2018-02-27 07:16:27  0.713333  10338.643333  10339.00  10338.286667
# 2018-02-27 07:16:46  0.010000  10341.045000  10341.05  10341.040000
#
#                            aq1        bq1     aqsum5     bqsum5     aqsum3  \
# order_date_time
# 2018-02-27 07:09:11  16.575512   0.008913  25.514852   8.869253  16.676512
# ...

# %%
#norepeat = norepeat[np.isfinite(odt['norepeat'])]

start=start.drop('diff', axis=1)
start=start.drop('norepeat', axis=1)
#start['zero']=0

# %%
#start.head(3)

# %%
len(start)
# Out:
# 42901

# %%
start['future_px'] = start['trade_px'].shift(-1)
print(start.columns.values)
# Out:
# ['Spread' 'trade_px' 'a1' 'b1' 'aq1' 'bq1' 'aqsum5' 'bqsum5' 'aqsum3'
#  'bqsum3' 'aqsum' 'bqsum' 'abq' 'abq5' 'abratio' 'id' 'distRatio5'
#  'distRatio10' 'trade_volume' 'abqdt' 'abqdt^2' 'rollingRatio' 'ratio3'
#  'ratio5' 'ratio5dt' 'sign_vol' 'abqsum' 'future_px']

# %%
start = start[['id','trade_px', 'future_px','aqsum','abqsum','bqsum','abqdt','aqsum3','abqdt^2', 'abq',
               'abq5','abratio', 'ratio3','Spread','ratio5','ratio5dt','distRatio5','distRatio10','sign_vol','trade_volume']]

# %%
plt.figure(figsize=(25,7))
plt.plot(start['trade_px'], label = 'starts only',linestyle='',marker='o',markersize=3,color='red')
plt.plot(odt['trade_px'], label = 'trade_px')

plt.legend(loc='upper left')
plt.show()

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(start)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.

# %%
start.reset_index(inplace=True)
start.head(3)
# Out:
#       order_date_time     id   trade_px  future_px      aqsum     abqsum  \
# 0 2018-02-27 07:09:11   28.0  10303.705  10301.005  63.586402  49.411315
# 1 2018-02-27 07:10:00  224.0  10301.005  10311.275  48.178458  33.368995
# 2 2018-02-27 07:10:41  409.0  10311.275  10313.435  25.022694  -6.809338
#
#        bqsum     abqdt     aqsum3   abqdt^2        abq       abq5   abratio  \
# 0  14.175087       NaN  16.676512       NaN  16.566599  16.645599  0.999463
# 1  14.809463  1.631992  10.735876  1.634492   5.019332  -1.681736  0.863120
# 2  31.832032  0.026108  12.909402 -2.061290   2.314509   9.478009  0.777300
#
#      ratio3  Spread    ratio5  ratio5dt  distRatio5  distRatio10  sign_vol  \
# 0  0.998150    0.01  0.742054       NaN        1.35         1.35       NaN
# 1  0.463683    0.01  0.464218 -0.006292       -0.50        -0.50  0.032865
# 2  0.790011    0.01  0.786469 -0.033994        3.58         3.58 -0.146682
#
#    trade_volume
# 0      0.000000
# 1      0.053969
# ...

# %%
start['price_change']=start['future_px']-start['trade_px']
#start.head(30)
start['before price_change']=1
#start['god_mode']=start['price_change' > 0].sum()
start['god_mode'] = np.where(start['price_change'] < 0, 0, start['price_change'])
start['god_mode'] = start['god_mode'].sum()
start.tail(3)
# Out:
#           order_date_time            id   trade_px  future_px      aqsum  \
# 42898 2018-03-06 19:33:28  3.405480e+06  10595.505  10598.545  20.048272
# 42899 2018-03-06 19:33:31  3.405534e+06  10598.545  10599.995  19.336767
# 42900 2018-03-06 19:34:04  3.651351e+06  10599.995        NaN  32.770461
#
#           abqsum      bqsum     abqdt     aqsum3   abqdt^2        abq  \
# 42898 -34.554312  54.602583  0.158858   3.713356  1.681013  -3.074000
# 42899 -43.674528  63.011295  0.220155   2.208217 -1.019690   0.083517
# 42900 -14.183202  46.953664       NaN  18.694604       NaN  12.108735
#
#             abq5   abratio    ratio3  Spread    ratio5  ratio5dt  distRatio5  \
# 42898  -0.579473  0.057571  0.463811    0.01  0.475322 -0.150352        0.16
# 42899   0.276877  0.551457  0.533443    0.01  0.529684  0.089978       -0.45
# 42900  16.785022  0.946963  0.907321    0.01  0.893115       NaN       -5.14
#
# ...

# %%
start.nlargest(5, 'price_change')
# Out:
#           order_date_time            id   trade_px     future_px       aqsum  \
# 41136 2018-03-06 00:02:28  3.000016e+06  11322.295  11379.685000   41.918603
# 33825 2018-03-01 20:54:02  1.257335e+06  10999.985  11049.995000  200.621816
# 31533 2018-02-28 21:55:30  8.061962e+05  10522.325  10565.165000   45.141794
# 55    2018-02-27 07:53:58  1.723956e+04  10493.995  10533.661667   12.500700
# 65    2018-02-27 07:57:53  2.220927e+04  10595.285  10634.140000   31.968397
#
#            abqsum      bqsum      abqdt      aqsum3    abqdt^2        abq  \
# 41136  -27.424713  69.343316   3.550016   31.769112  -3.393539   9.682942
# 33825  119.102232  81.519584   2.797722  195.844971   3.556515  -9.060583
# 31533    5.267162  39.874632  -1.546497    6.447104   0.078533  -5.348913
# 55     -56.837034  69.337733 -59.758234    0.674715  -1.668305 -11.515411
# 65     -29.870526  61.838924 -30.170468   24.489634 -21.244584  11.966766
#
# ...

# %%
outliers= start.loc[abs(start['price_change']) > 15].index
#df.loc[df['column_name'] == some_value
start=start.drop(outliers)
outliers= start.loc[abs(start['price_change']) < .25].index
#df.loc[df['column_name'] == some_value
start=start.drop(outliers)

# %%
pd.options.display.max_columns = 999
(df.ix[(df['id']-100).abs().argsort()[:5]])
# Out:
# C:\Users\Jason\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate_ix
#      id   trade_px  trade_volume       b1        b2        b3        b4  \
# 16  101  10303.705      0.013500  10303.7  10302.96  10302.87  10302.42
# 17  105  10303.705      0.013500  10303.7  10302.96  10302.87  10302.42
# 18  107  10303.705      0.013941  10303.7  10302.96  10302.87  10302.42
# 19  108  10303.705      0.007400  10303.7  10302.96  10302.87  10302.42
# 20  110  10303.705      0.001513  10303.7  10302.96  10302.87  10302.42
#
#           b5        b6        b7        b8        b9      b10       b11  \
# 16  10301.46  10301.18  10301.03  10300.02  10300.01  10300.0  10299.53
# 17  10301.46  10301.18  10301.03  10300.02  10300.01  10300.0  10299.53
# ...

# %%
plt.scatter( start['abq'], start['price_change'], label = 'abq1')
plt.scatter(start['abq5'], start['price_change'], label = 'abq5')
plt.legend(loc='upper left')
plt.suptitle('Order book sum vs. Price Change', fontsize=20)
plt.ylabel('Price Change', fontsize=18)
plt.xlabel('Order Book sum', fontsize=16)
plt.ylim( (-20, 20) )
plt.xlim(-60, 60)
plt.show()

# %%
plt.scatter(start['trade_volume'], start['price_change'])
plt.suptitle('Order book sum vs. Price Change', fontsize=20)
plt.ylabel('Price Change', fontsize=18)
plt.xlabel('Volume', fontsize=16)
plt.show()

# %%
slope, intercept, r_value, p_value, std_err = stats.linregress(start['abratio'], start['price_change'])
print("r-squared:", r_value**2)
# Out:
# r-squared: nan
# C:\Users\Jason\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Users\Jason\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Users\Jason\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)

# %%
plt.scatter(start['abratio'], start['price_change'] )
plt.suptitle('Price Change vs. ab ratio', fontsize=20)
plt.plot(start['abratio'], intercept + slope*(start['abratio']), 'r', label='fitted line')
plt.ylabel('Price Change', fontsize=18)
plt.xlabel('ratio', fontsize=16)
plt.ylim( (-10, 10) )
plt.xlim(0, 1)
plt.show()

# %%
slope, intercept, r_value, p_value, std_err = stats.linregress(start['ratio5'], start['price_change'])
print("r-squared:", r_value**2)
# Out:
# r-squared: nan
# C:\Users\Jason\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Users\Jason\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Users\Jason\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)

# %%
plt.scatter(start['ratio5'], start['price_change'],color='blue' )
plt.plot(start['ratio5'], intercept + slope*(start['ratio5']), 'r', label='fitted line')
#plt.scatter(start['abratio'], start['price_change'], color='red' )
plt.suptitle('Price Change vs. ratio5', fontsize=20)
plt.ylabel('Price Change', fontsize=18)
plt.xlabel('ratio5', fontsize=16)
plt.ylim( (-10, 10) )
plt.xlim(0, 1)
plt.show()

# %%
plt.scatter(start['ratio3'], start['price_change'],color='blue' )
plt.plot(start['ratio3'], intercept + slope*(start['ratio3']), 'r', label='fitted line')
#plt.scatter(start['abratio'], start['price_change'], color='red' )
plt.suptitle('Price Change vs. ratio3', fontsize=20)
plt.ylabel('Price Change', fontsize=18)
plt.xlabel('ratio3', fontsize=16)
plt.ylim( (-10, 10) )
plt.xlim(0, 1)
plt.show()

# %%
plt.scatter((start['distRatio10']), start['price_change'],color='blue' )
#plt.plot(start['ratio5'], intercept + slope*(start['ratio5']), 'r', label='fitted line')
#plt.scatter(start['abratio'], start['price_change'], color='red' )
plt.suptitle('Price Change vs. distRatio10', fontsize=20)
plt.ylabel('Price Change', fontsize=18)
plt.xlabel('ratio5', fontsize=16)
plt.ylim( (-10, 10) )
#plt.xlim(0, 1)
plt.show()

# %%
plt.scatter((start['aqsum']-start['aqsum3']), start['price_change'],color='blue' )
#plt.plot(start['ratio5'], intercept + slope*(start['ratio5']), 'r', label='fitted line')
#plt.scatter(start['abratio'], start['price_change'], color='red' )
plt.suptitle('Price Change vs. ratio5', fontsize=20)
plt.ylabel('Price Change', fontsize=18)
plt.xlabel('ratio5', fontsize=16)
plt.ylim( (-10, 10) )
#plt.xlim(0, 1)
plt.show()

# %%
plt.scatter(start['sign_vol'], start['price_change'] )
plt.suptitle('Price Change vs. Sign Volume', fontsize=20)
plt.ylabel('Price Change', fontsize=18)
plt.xlabel('sign_vol', fontsize=16)
plt.ylim( (-10, 10) )
plt.xlim(-1, 1)
plt.show()

# %%
plt.scatter(start['abqdt'], start['price_change'] )
plt.suptitle('Price Change vs. AB dt over time', fontsize=20)
plt.ylabel('Price Change', fontsize=18)
plt.xlabel('aq dt', fontsize=16)
plt.ylim( (-10, 10) )
plt.xlim(-10, 10)
plt.show()

# %%
plt.scatter(start['ratio5dt'], start['price_change'] )
plt.suptitle('Price Change vs. AB dt over time', fontsize=20)
plt.ylabel('Price Change', fontsize=18)
plt.xlabel('aq dt', fontsize=16)
plt.ylim( (-10, 10) )
plt.xlim(-.3,.3)
plt.show()

# %%
start.dropna(axis=0, how='any', inplace=True)
start.to_csv('C:\\Users\\Jason\\Documents\\Python\\Stock Market Prediction\\Crypto\\BTC_Slopes.csv',index=False)
